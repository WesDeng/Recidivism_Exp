# %%
import os
import numpy as np
import pandas as pd

# %%
import random

df = pd.read_csv('./Step2.csv')
df2 = pd.read_csv('./Quizdup.csv')
#random.sample(range(len(df["Username"])), len(df["Username"]))
deidentify_id = [0,16,38,30,43,49,54,47,12,42,55,44,14,32,36,45,11,4,60,24,39,58,
 23,
 13,
 46,
 31,
 41,
 51,
 17,
 22,
 27,
 21,
 53,
 26,
 5,
 9,
 56,
 59,
 48,
 28,
 34,
 20,
 57,
 6,
 15,
 61,
 10,
 37,
 18,
 7,
 25,
 40,
 50,
 33,
 1,
 29,
 2,
 3,
 52,
 19,
 8,
 35]

df["id"] = deidentify_id

persona = []

for andrew in df["Username"]:
    name = andrew.split('@')
    if name[0] in ['chuqiaos', 'sanilsar', 'ashashki','hyunm', 'mingzhe2', 'raajatg', 'awilbour','yuxilee']:
        persona.append('Judge')    
    elif(name[0] in ['vzz', 'sjang1','ryankenn', 'cleelama', 'jdiei','araina', 'dgajaraw','yunmino']):
        persona.append('Defendent')
    elif(name[0] in ['yihaop', 'sanag', 'jaclyny','ysato','abonilla', 'mpeswani','agyang','xinrany']):
        persona.append('Community Member')
    elif(name[0] in ['kwang2', 'cheukyil', 'yuhanliu', 'mnaidu','amfang','changc','gzhao','chenxuli']):
        persona.append('Fairness Advocate')
    else:
        persona.append('NA')

count = 0
for x in range(len(persona)):
    if persona[x] != 'NA':
        count += 1
df["Persona"] = persona
name_to_metrics = {}
for x in range(len(df2["name"])):
    name_to_metrics[df2["name"][x]] = df2["Metric"][x]

preferred = []
name_to_username = []
found = False
#print(len(name_to_metrics))
df["Full Name"] = df2["Full Name"]
for x in df["Full Name"]:
    preferred.append(name_to_metrics[x])
df["metric"] = preferred

df.head()
# Out:
#                    Timestamp                 Username  \
# 0  2020/09/10 1:47:36 PM MDT    amfang@andrew.cmu.edu
# 1  2020/09/10 1:48:52 PM MDT     jdiei@andrew.cmu.edu
# 2  2020/09/10 1:49:04 PM MDT     ysato@andrew.cmu.edu
# 3  2020/09/10 1:49:09 PM MDT  ashashki@andrew.cmu.edu
# 4  2020/09/10 1:49:36 PM MDT  cheukyil@andrew.cmu.edu
#
#   Among the 8 model cards, which one would you choose for designing a recidivism prediction algorithm? Please pick your first choice below.  \
# 0                                            Model_2
# 1                                            Model_5
# 2                                            Model_8
# 3                                            Model_3
# 4                                            Model_4
#
#   Among the 8 model cards, which one would you choose for designing a recidivism prediction algorithm? Please pick your second top choice below.  \
# 0                                            Model_4
# 1                                            Model_7
# 2                                            Model_2
# 3                                            Model_7
# 4                                            Model_4
#
#              Please elaborate on your answer above.   id            Persona  \
# 0  As a fairness advocate, I aim for the lowest p...   0  Fairness Advocate
# 1  Model 5 has the lowest false positive rate of ...  16          Defendent
# 2  My first choice is model 8 because it has the ...  38   Community Member
# 3  Since I am playing the judge role, I am lookin...  30              Judge
# 4  Since we want to be fair, we want to minimize ...  43  Fairness Advocate
#
#                    Full Name  \
# 0                  Anna Fang
# 1                    JM Diei
# 2                  Yumi Sato
# 3  Alice Shashkina Shashkina
# 4                Phipson Lee
#
#                                               metric
# 0                                Maximizing Accuracy
# 1  Minimizing False Positive Rate,Maximizing Accu...
# 2  Minimizing disparity (of FPRs\, FNRs\, accurac...
# 3                      Maximizing True Positive Rate
# 4  Minimizing disparity (of FPRs\, FNRs\, accurac...

# %%
df
# Out:
#                     Timestamp                 Username  \
# 0   2020/09/10 1:47:36 PM MDT    amfang@andrew.cmu.edu
# 1   2020/09/10 1:48:52 PM MDT     jdiei@andrew.cmu.edu
# 2   2020/09/10 1:49:04 PM MDT     ysato@andrew.cmu.edu
# 3   2020/09/10 1:49:09 PM MDT  ashashki@andrew.cmu.edu
# 4   2020/09/10 1:49:36 PM MDT  cheukyil@andrew.cmu.edu
# ..                        ...                      ...
# 57  2020/09/11 8:28:13 AM MDT  chenxuli@andrew.cmu.edu
# 58  2020/09/11 8:29:09 AM MDT   pkoppol@andrew.cmu.edu
# 59  2020/09/11 8:29:40 AM MDT   yunmino@andrew.cmu.edu
# 60  2020/09/11 8:30:25 AM MDT   yuxilee@andrew.cmu.edu
# 61  2020/09/11 8:30:31 AM MDT    agyang@andrew.cmu.edu
#
#    Among the 8 model cards, which one would you choose for designing a recidivism prediction algorithm? Please pick your first choice below.  \
# 0                                             Model_2
# 1                                             Model_5
# 2                                             Model_8
# 3                                             Model_3
# 4                                             Model_4
# ..                                                ...
# 57                                            Model_2
# 58                                            Model_2
# 59                                            Model_5
# 60                                            Model_3
# 61                                            Model_2
#
#    Among the 8 model cards, which one would you choose for designing a recidivism prediction algorithm? Please pick your second top choice below.  \
# 0                                             Model_4
# 1                                             Model_7
# 2                                             Model_2
# 3                                             Model_7
# 4                                             Model_4
# ..                                                ...
# 57                                            Model_4
# 58                                            Model_8
# 59                                            Model_7
# 60                                            Model_7
# 61                                            Model_8
#
#               Please elaborate on your answer above.
# 0   As a fairness advocate, I aim for the lowest p...
# 1   Model 5 has the lowest false positive rate of ...
# 2   My first choice is model 8 because it has the ...
# 3   Since I am playing the judge role, I am lookin...
# 4   Since we want to be fair, we want to minimize ...
# ..                                                ...
# 57  I choose models 2 & 4 because from my(fairness...
# 58  As a community member concerned with reduced F...
# 59  As a defendant, I needed a model that has lowe...
# 60  As the judge, I wanted to select a predictive ...
# 61  As a community member, my priority is minimizi...
#
# [62 rows x 5 columns]

# %%
df = df.rename(columns={"Among the 8 model cards, which one would you choose for designing a recidivism prediction algorithm? Please pick your first choice below." : "ind_1", "Among the 8 model cards, which one would you choose for designing a recidivism prediction algorithm? Please pick your second top choice below." : "ind_2"})
df.head()
# Out:
#                    Timestamp                 Username    ind_1    ind_2  \
# 0  2020/09/10 1:47:36 PM MDT    amfang@andrew.cmu.edu  Model_2  Model_4
# 1  2020/09/10 1:48:52 PM MDT     jdiei@andrew.cmu.edu  Model_5  Model_7
# 2  2020/09/10 1:49:04 PM MDT     ysato@andrew.cmu.edu  Model_8  Model_2
# 3  2020/09/10 1:49:09 PM MDT  ashashki@andrew.cmu.edu  Model_3  Model_7
# 4  2020/09/10 1:49:36 PM MDT  cheukyil@andrew.cmu.edu  Model_4  Model_4
#
#              Please elaborate on your answer above.
# 0  As a fairness advocate, I aim for the lowest p...
# 1  Model 5 has the lowest false positive rate of ...
# 2  My first choice is model 8 because it has the ...
# 3  Since I am playing the judge role, I am lookin...
# 4  Since we want to be fair, we want to minimize ...

# %%
group = [11,11,10,9,8,13,9,7,6,4,7,5,6,5,2,11,8,3,4,2,12,10,5,3,13,9,11,7
,1,14,4,9,1,8,13,8,13,14,1,14,3,10,12,5,6,4,3,6,7,1,2,2,12,14,15,10,12,15,15,15,15,15]

# %%
len(group)
# Out:
# 62

# %%
# Check group number. 
for i in range(1, 17):
    count = 0
    for num in group:
        if num == i:
            count += 1
    print("%d has %d" % (i, count))
# Out:
# 1 has 4
# 2 has 4
# 3 has 4
# 4 has 4
# 5 has 4
# 6 has 4
# 7 has 4
# 8 has 4
# 9 has 4
# 10 has 4
# 11 has 4
# 12 has 4
# 13 has 4
# 14 has 4
# 15 has 6
# 16 has 0

# %%
df['group_num'] = group

# %%
# delete group 14. 
df_no14 = df[df['group_num'] != 14]

# %%
df_no14.to_csv('pre_test.csv')

# %%
# Switch columns order. 
cols = df_no14.columns.tolist()
cols
# Out:
# ['Timestamp',
#  'Username',
#  'ind_1',
#  'ind_2',
#  'Please elaborate on your answer above. ',
#  'group_num']

# %%
df_prev = df_no14.rename(columns = {'Please elaborate on your answer above. ' : "ind_reason"})

# %%
cols = df_prev.columns.tolist()
cols
# Out:
# ['Timestamp', 'Username', 'ind_1', 'ind_2', 'ind_reason', 'group_num']

# %%
cols = ['Timestamp', 'Username', 'group_num', 'ind_1', 'ind_2', 'ind_reason']
df_prev = df_prev[cols]
df_prev.head()
# Out:
#                    Timestamp                 Username  group_num    ind_1  \
# 0  2020/09/10 1:47:36 PM MDT    amfang@andrew.cmu.edu         11  Model_2
# 1  2020/09/10 1:48:52 PM MDT     jdiei@andrew.cmu.edu         11  Model_5
# 2  2020/09/10 1:49:04 PM MDT     ysato@andrew.cmu.edu         10  Model_8
# 3  2020/09/10 1:49:09 PM MDT  ashashki@andrew.cmu.edu          9  Model_3
# 4  2020/09/10 1:49:36 PM MDT  cheukyil@andrew.cmu.edu          8  Model_4
#
#      ind_2                                         ind_reason
# 0  Model_4  As a fairness advocate, I aim for the lowest p...
# 1  Model_7  Model 5 has the lowest false positive rate of ...
# 2  Model_2  My first choice is model 8 because it has the ...
# 3  Model_7  Since I am playing the judge role, I am lookin...
# 4  Model_4  Since we want to be fair, we want to minimize ...

# %%
df_prev.to_csv('df_prev.csv')

# %%
df_prev
# Out:
#                     Timestamp                 Username  group_num    ind_1  \
# 0   2020/09/10 1:47:36 PM MDT    amfang@andrew.cmu.edu         11  Model_2
# 1   2020/09/10 1:48:52 PM MDT     jdiei@andrew.cmu.edu         11  Model_5
# 2   2020/09/10 1:49:04 PM MDT     ysato@andrew.cmu.edu         10  Model_8
# 3   2020/09/10 1:49:09 PM MDT  ashashki@andrew.cmu.edu          9  Model_3
# 4   2020/09/10 1:49:36 PM MDT  cheukyil@andrew.cmu.edu          8  Model_4
# 5   2020/09/10 1:49:45 PM MDT   xinrany@andrew.cmu.edu         13  Model_8
# 6   2020/09/10 1:49:49 PM MDT  ryankenn@andrew.cmu.edu          9  Model_7
# 7   2020/09/10 1:50:05 PM MDT       vzz@andrew.cmu.edu          7  Model_5
# 8   2020/09/10 1:50:14 PM MDT     azizg@andrew.cmu.edu          6  Model_1
# 9   2020/09/10 1:50:46 PM MDT  jeongkes@andrew.cmu.edu          4  Model_6
# 10  2020/09/10 1:51:28 PM MDT    kwang2@andrew.cmu.edu          7  Model_2
# 11  2020/09/10 1:51:49 PM MDT  aroviros@andrew.cmu.edu          5  Model_3
# 12  2020/09/10 1:51:53 PM MDT    njwong@andrew.cmu.edu          6  Model_2
# 13  2020/09/10 1:51:58 PM MDT  ddomalik@andrew.cmu.edu          5  Model_7
# 14  2020/09/10 1:52:07 PM MDT   vkamath@andrew.cmu.edu          2  Model_5
# 15  2020/09/10 1:52:42 PM MDT  mingzhe2@andrew.cmu.edu         11  Model_3
# 16  2020/09/10 1:53:02 PM MDT    sjang1@andrew.cmu.edu          8  Model_7
# 17  2020/09/10 1:53:11 PM MDT   lmchong@andrew.cmu.edu          3  Model_7
# 18  2020/09/10 1:53:14 PM MDT    mkomar@andrew.cmu.edu          4  Model_2
# 19  2020/09/10 1:53:18 PM MDT  xiaoyinm@andrew.cmu.edu          2  Model_7
# 20  2020/09/10 1:53:44 PM MDT   raajatg@andrew.cmu.edu         12  Model_3
# 21  2020/09/10 1:54:04 PM MDT  cleelama@andrew.cmu.edu         10  Model_5
# 22  2020/09/10 1:54:18 PM MDT  pvichiva@andrew.cmu.edu          5  Model_3
# 23  2020/09/10 1:54:50 PM MDT  hsienhuh@andrew.cmu.edu          3  Model_5
# 24  2020/09/10 1:55:44 PM MDT  awilbour@andrew.cmu.edu         13  Model_3
# 25  2020/09/10 1:55:51 PM MDT   jaclyny@andrew.cmu.edu          9  Model_8
# 26  2020/09/10 1:55:57 PM MDT  abonilla@andrew.cmu.edu         11  Model_8
# 27  2020/09/10 1:56:13 PM MDT        yihaop@cs.cmu.edu          7  Model_8
# 28  2020/09/10 1:56:26 PM MDT    claraw@andrew.cmu.edu          1  Model_1
# 30  2020/09/10 1:57:05 PM MDT  yunqiaox@tepper.cmu.edu          4  Model_3
# 31  2020/09/10 1:58:10 PM MDT  yuhanliu@andrew.cmu.edu          9  Model_2
# 32  2020/09/10 1:58:21 PM MDT  liangzhl@andrew.cmu.edu          1  Model_4
# 33  2020/09/10 1:58:21 PM MDT     sanag@andrew.cmu.edu          8  Model_8
# 34  2020/09/10 1:58:33 PM MDT     gzhao@andrew.cmu.edu         13  Model_2
# 35  2020/09/10 1:59:14 PM MDT  sanilsar@andrew.cmu.edu          8  Model_3
# 36  2020/09/10 1:59:52 PM MDT  dgajaraw@andrew.cmu.edu         13  Model_5
# 38  2020/09/10 2:00:27 PM MDT  rdparikh@andrew.cmu.edu          1  Model_4
# 40  2020/09/10 2:01:02 PM MDT   bsheng2@andrew.cmu.edu          3  Model_2
# 41  2020/09/10 2:01:07 PM MDT    mnaidu@tepper.cmu.edu         10  Model_2
# 42  2020/09/10 2:01:28 PM MDT  mpeswani@andrew.cmu.edu         12  Model_8
# 43  2020/09/10 2:01:32 PM MDT  charleyz@andrew.cmu.edu          5  Model_4
# 44  2020/09/10 2:03:05 PM MDT    nehalg@andrew.cmu.edu          6  Model_5
# 45  2020/09/10 2:03:09 PM MDT       jx2@andrew.cmu.edu          4  Model_3
# 46  2020/09/10 2:03:40 PM MDT   tarikaj@andrew.cmu.edu          3  Model_8
# 47  2020/09/10 2:04:01 PM MDT     laiw2@andrew.cmu.edu          6  Model_4
# 48  2020/09/10 2:05:02 PM MDT  chuqiaos@andrew.cmu.edu          7  Model_3
# 49  2020/09/10 2:05:22 PM MDT    ppowar@andrew.cmu.edu          1  Model_3
# 50  2020/09/10 2:05:25 PM MDT    mhasey@andrew.cmu.edu          2  Model_3
# 51  2020/09/10 2:05:56 PM MDT    yiweih@andrew.cmu.edu          2  Model_3
# 52  2020/09/10 2:07:26 PM MDT    changc@andrew.cmu.edu         12  Model_2
# 54  2020/09/10 2:11:11 PM MDT  acfriedm@andrew.cmu.edu         15  Model_3
# 55  2020/09/10 3:52:29 PM MDT     hyunm@andrew.cmu.edu         10  Model_3
# 56  2020/09/10 6:09:16 PM MDT    araina@andrew.cmu.edu         12  Model_7
# 57  2020/09/11 8:28:13 AM MDT  chenxuli@andrew.cmu.edu         15  Model_2
# 58  2020/09/11 8:29:09 AM MDT   pkoppol@andrew.cmu.edu         15  Model_2
# 59  2020/09/11 8:29:40 AM MDT   yunmino@andrew.cmu.edu         15  Model_5
# 60  2020/09/11 8:30:25 AM MDT   yuxilee@andrew.cmu.edu         15  Model_3
# 61  2020/09/11 8:30:31 AM MDT    agyang@andrew.cmu.edu         15  Model_2
#
#       ind_2                                         ind_reason
# 0   Model_4  As a fairness advocate, I aim for the lowest p...
# 1   Model_7  Model 5 has the lowest false positive rate of ...
# 2   Model_2  My first choice is model 8 because it has the ...
# 3   Model_7  Since I am playing the judge role, I am lookin...
# 4   Model_4  Since we want to be fair, we want to minimize ...
# 5   Model_2  If my goal is to choose a model that minimizes...
# 6   Model_3  My primary heuristic was selecting a model wit...
# 7   Model_7  As a defendant, I want the lowest FPR. Models ...
# 8   Model_3  I ranked my top two categories as 1. Accuracy ...
# 9   Model_2  The risk of false negative is much higher than...
# 10  Model_4  My persona was the fairness advocate, who want...
# 11  Model_1  dont want to punish good people. thought this ...
# 12  Model_8  Overall, in a system for checking recidivism, ...
# 13  Model_3  For a recidivism algorithm, I'm particularly w...
# 14  Model_3  Model 5 is fair to both groups and Model 3 is ...
# 15  Model_7  As a judge, I care more about the overall accu...
# 16  Model_5  These models have the lowest false positive ra...
# 17  Model_5  I made those decision because I thought the FP...
# 18  Model_8  I believe that the lower the false negative ra...
# 19  Model_5  I focused mainly on the accuracy and the lowes...
# 20  Model_7  Ultimately, in a criminal justice system, we w...
# 21  Model_7  As a defendant, I would want a lower FPR rate,...
# 22  Model_7  Since I did not think that there is much worse...
# 23  Model_7  model 5 and 7 have the lowest FPR for African ...
# 24  Model_1  Both these models have high accuracy - my firs...
# 25  Model_2  As a community member, I would like the model ...
# 26  Model_2  As a Community member, I would prioritize the ...
# 27  Model_2  As a community member, I would say I care more...
# 28  Model_4  I think that these two models did relatively w...
# 30  Model_7                                          No reason
# 31  Model_4  The persona for me is to advocate the model wi...
# 32  Model_3  It's a difficult choice. Both models produces ...
# 33  Model_2  As a community member who values safety my fir...
# 34  Model_5  Since I'm a fairness advocate, I want the mode...
# 35  Model_2  Model 3 has the highest accuracy while Model 2...
# 36  Model_7  I would pick model 5 as my first choice, becau...
# 38  Model_8  I have selected models which minimize disparit...
# 40  Model_5  I will not put the accuracy in the first place...
# 41  Model_4  These 2 models have relatively lower disparity...
# 42  Model_2  As a community member, I am more concerned tha...
# 43  Model_1  Model 4 and 1 seem to have a high accuracy rat...
# 44  Model_7  Model 5 has low FPR and higher FNR and hence i...
# 45  Model_4  There are no attributes that perform relativel...
# 46  Model_2  Looking at the lowest false negative rate, whi...
# 47  Model_3  4 has a better Dis/Acc, and also the FPR/FNR a...
# 48  Model_7  As a judge I want the model to have higher acc...
# 49  Model_5  These two models have a good accuracy rate. Th...
# 50  Model_1  model 3: Highest accuracy at aprox. 70%, fairl...
# 51  Model_5  In a recidivism prediction, the important metr...
# 52  Model_4                 low disparity, high false positive
# 54  Model_4  Model 3 is the best b/c it has the highest acc...
# 55  Model_7  I am a judge, I have to make a accurate decisi...
# 56  Model_3  Model 7 has an overall balanced performance fo...
# 57  Model_4  I choose models 2 & 4 because from my(fairness...
# 58  Model_8  As a community member concerned with reduced F...
# 59  Model_7  As a defendant, I needed a model that has lowe...
# 60  Model_7  As the judge, I wanted to select a predictive ...
# 61  Model_8  As a community member, my priority is minimizi...
